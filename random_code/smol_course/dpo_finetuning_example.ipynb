# %%
from huggingface_hub import login

login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import os
import gc
import torch

import transformers
from transformers import AutoModelForCausalLM, AutoTokenizer, TrainingArguments
from datasets import load_dataset
from trl import DPOTrainer, DPOConfig

# %% [markdown]
# ## Format dataset

# %%
# Load dataset
dataset = load_dataset("trl-lib/ultrafeedback_binarized")

# %% [markdown]
# ## Select the model
#
# We will use the SmolLM2-135M-Instruct model which has already been through a SFT training, so it it compatible with DPO. You can also use the model you trained in [1_supervised_finetuning](../1_supervised_finetuning/notebooks/sft_finetuning_example.ipynb).

# %%
dataset[0]
# Out:
# {'chosen': [{'content': 'Use the pygame library to write a version of the classic game Snake, with a unique twist',
#    'role': 'user'},
#   {'content': "Sure, I'd be happy to help you write a version of the classic game Snake using the pygame library! Here's a basic outline of how we can approach this:\n\n1. First, we'll need to set up the game display and create a game object that we can use to handle the game's state.\n2. Next, we'll create the game's grid, which will be used to represent the game board. We'll need to define the size of the grid and the spaces within it.\n3. After that, we'll create the snake object, which will be used to represent the player's movement. We'll need to define the size of the snake and the speed at which it moves.\n4. We'll also need to create a food object, which will be used to represent the food that the player must collect to score points. We'll need to define the location of the food and the speed at which it moves.\n5. Once we have these objects set up, we can start handling the game's logic. We'll need to define the rules for the player's movements, such as how the player can move the snake and how the snake will grow as the player collects more food.\n6. We'll also need to add collisions detection to the game, so that the snake and the food can collide with each other.\n7. Finally, we'll need to add a user interface to the game, such as a menu and a scoreboard.\n\nNow, as for the unique twist, we could add a few features to make the game more interesting. For example, we could add power-ups that give the player special abilities, such as the ability to grow the snake faster or to change its direction. We could also add obstacles, such as walls or pits, that the player must avoid.\n\nHere's some sample code to get us started:\n```\nimport pygame\n\n# Initialize pygame\npygame.init()\n\n# Set up the game display\nwidth = 800\nheight = 600\nscreen = pygame.display.set_mode((width, height))\n\n# Define the colors\nWHITE = (255, 255, 255)\nBLACK = (0, 0, 0)\nGREEN = (0, 255, 0)\n\n# Define the game objects\nsnake = pygame.Rect(50, 50, 10, 10)\nfood = pygame.Rect(100, 100, 10, 10)\n\n# Define the game logic\ndef update_snake():\n    # Get the mouse position\n    mouse_pos = pygame.mouse.get_pos()\n\n    # Move the snake based on the mouse position\n    if mouse_pos[0] > snake.x:\n        snake.x += 10\n    elif mouse_pos[0] < snake.x:\n        snake.x -= 10\n    elif mouse_pos[1] > snake.y:\n        snake.y += 10\n    elif mouse_pos[1] < snake.y:\n        snake.y -= 10\n\n    # Update the snake's size\n    if snake.x == food.x and snake.y == food.y:\n        snake.width += 10\n        snake.height += 10\n\n# Define the game loop\ndef game_loop():\n    # Clear the screen\n    screen.fill(BLACK)\n\n    # Update the game objects\n    update_snake()\n\n    # Draw the game objects\n    screen.fill(WHITE)\n    screen.draw.rect(snake, GREEN)\n    screen.draw.rect(food, BLACK)\n\n    # Update the display\n    pygame.display.flip()\n\n# Start the game loop\ngame_loop()\n\n# Run the game\nwhile True:\n    for event in pygame.event.get():\n        if event.type == pygame.QUIT:\n            pygame.quit()\n            break\n\n    pygame.time.Clock().tick(60)\n```\nThis code sets up a basic game display, defines the snake and food objects, and updates the game state based on the player's movements. We've also added a simple user interface and some basic collision detection.\n\nAs for the unique twist, we could add a few features to make the game",
#    'role': 'assistant'}],
#  'rejected': [{'content': 'Use the pygame library to write a version of the classic game Snake, with a unique twist',
#    'role': 'user'},
#   {'content': 'Sure, here\'s an example of how to write a version of Snake game with a unique twist using the Pygame library:\n```python\nimport pygame\n\nclass SnakeGame:\n    def __init__(self, game_width, game_height):\n        pygame.init()\n        screen = pygame.display.set_mode((game_width, game_height))\n        pygame.display.set_caption("Snake Game")\n        self.speed = 5  # Speed of the snake\n        self.food_speed = 1  # Speed of the food\n        self.direction = 0  # Initial direction of the snake\n        self.snakelen = 0  # Length of the snake\n        self.food = pygame.image.load("snake_food.png")\n        self.head = pygame.image.load("snake_head.png")\n        self.tail = pygame.image.load("snake_tail.png")\n        self.game Quint()\n    def Quint(self):\n        for i in range(50):\n            pygame.draw.line(screen, (180, 100, 220), (0, 0, 200), 2)\n            pygame.draw.line(screen, (180, 100, 220), (50, 0, 200), 2)\n            pygame.draw.line(screen, (180, 100, 220), (50, 50, 200), 2)\n            pygame.draw.line(screen, (180, 100, 220), (50, 50, 300), 2)\n            pygame.draw.line(screen, (180, 100, 220), (50, 80, 200), 2)\n            pygame.draw.line(screen, (180, 100, 220), (50, 80, 300), 2)\n            pygame.draw.line(screen, (180, 100, 220), (0, 50, 200), 2)\n            pygame.draw.line(screen, (180, 100, 220), (0, 50, 300), 2)\n            pygame.draw.line(screen, (180, 100, 220), (0, 80, 200), 2)\n            pygame.draw.line(screen, (180, 100, 220), (0, 80, 300), 2)\n            pygame.display.flip()\n        self.game.run()\n    def run(self):\n        while True:\n            for event in pygame.event. pygame.KEYDOWN:\n                if event.key == pygame.K_LEFT:\n                    self.direction = -1\n                if event.key == pygame.K_RIGHT:\n                    self.direction = 1\n            self.snakelen += 1\n            if self.snakelen == 0:\n                self.snakelen = 10\n            if self.snakelen > 20:\n                self.snakelen = 20\n            self.gameQuint()\n            self.foodCrossing()\n            self.headRun()\n            pygame.display.update()\ngame = SnakeGame(800, 600)\ngame.run()\n```\nIn this game, the snake moves with a constant speed, but the direction of the snake can be controlled by the user using the left and right arrow keys. The snake grows in length every 10 segments, and when it reaches a certain length, it resets to 10 segments. The food moves fast and randomly crosses the screen, and the snake can eat it by colliding with it. The snake\'s head and tail move independently of each other. The game ends when the snake dies or reaches the end of the screen.',
#    'role': 'assistant'}],
#  'score_chosen': 6.0,
#  'score_rejected': 4.0}

# %%
# TODO: 🦁 change the model to the path or repo id of the model you trained in [1_instruction_tuning](../../1_instruction_tuning/notebooks/sft_finetuning_example.ipynb)

model_name = "HuggingFaceTB/SmolLM2-135M-Instruct"

device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)

# Model to fine-tune
model = AutoModelForCausalLM.from_pretrained(
    pretrained_model_name_or_path=model_name,
    torch_dtype=torch.float32
).to(device)
model.config.use_cache = False
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token

# Set our name for the finetune to be saved &/ uploaded to
finetune_name = "SmolLM2-FT-DPO"
finetune_tags = ["smol-course", "module_1"]

# %% [markdown]
# ## Train model with DPO

# %%
# Training arguments
training_args = DPOConfig(
    # Training batch size per GPU
    per_device_train_batch_size=4,
    # Number of updates steps to accumulate before performing a backward/update pass
    # Effective batch size = per_device_train_batch_size * gradient_accumulation_steps
    gradient_accumulation_steps=4,
    # Saves memory by not storing activations during forward pass
    # Instead recomputes them during backward pass
    gradient_checkpointing=True,
    # Base learning rate for training
    learning_rate=5e-5,
    # Learning rate schedule - 'cosine' gradually decreases LR following cosine curve
    lr_scheduler_type="cosine",
    # Total number of training steps
    max_steps=200,
    # Disables model checkpointing during training
    save_strategy="no",
    # How often to log training metrics
    logging_steps=1,
    # Directory to save model outputs
    output_dir="smol_dpo_output",
    # Number of steps for learning rate warmup
    warmup_steps=100,
    # Use bfloat16 precision for faster training
    bf16=True,
    # Disable wandb/tensorboard logging
    report_to=None,
    # Keep all columns in dataset even if not used
    remove_unused_columns=False,
    # Enable MPS (Metal Performance Shaders) for Mac devices
    # Model ID for HuggingFace Hub uploads
    hub_model_id=finetune_name,
)

# %%
trainer = DPOTrainer(
    # The model to be trained
    model=model,
    # Training configuration from above
    args=training_args,
    # Dataset containing preferred/rejected response pairs
    train_dataset=dataset,
    # Tokenizer for processing inputs
    processing_class=tokenizer,
    # DPO-specific temperature parameter that controls the strength of the preference model
    # Lower values (like 0.1) make the model more conservative in following preferences
    beta=0.1,
    # Maximum length of the input prompt in tokens
    max_prompt_length=1024,
    # Maximum combined length of prompt + response in tokens
    max_length=1536,
)
# Out:
# c:\Users\kevor\anaconda3\envs\smol_course\Lib\site-packages\huggingface_hub\utils\_deprecation.py:100: FutureWarning: Deprecated argument(s) used in '__init__': max_prompt_length, max_length. Will not be supported from version '0.13.0'.
#
# Deprecated positional argument(s) used in DPOTrainer, please use the DPOConfig to set these arguments instead.
#   warnings.warn(message, FutureWarning)
# c:\Users\kevor\anaconda3\envs\smol_course\Lib\site-packages\trl\trainer\dpo_trainer.py:469: UserWarning: You passed `max_length` to the DPOTrainer, the value you passed will override the one in the `DPOConfig`.
#   warnings.warn(
# c:\Users\kevor\anaconda3\envs\smol_course\Lib\site-packages\trl\trainer\dpo_trainer.py:475: UserWarning: You passed `max_prompt_length` to the DPOTrainer, the value you passed will override the one in the `DPOConfig`.
#   warnings.warn(
# max_steps is given, it will override any value given in num_train_epochs

# %%
# Train the model
trainer.train()
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# Could not estimate the number of tokens of the input, floating-point operations will not be computed
# {'loss': 0.6931, 'grad_norm': 80.11817932128906, 'learning_rate': 5.000000000000001e-07, 'rewards/chosen': 0.0, 'rewards/rejected': 0.0, 'rewards/accuracies': 0.0, 'rewards/margins': 0.0, 'logps/chosen': -453.22967529296875, 'logps/rejected': -332.1123352050781, 'logits/chosen': 4.746685028076172, 'logits/rejected': 4.014349937438965, 'epoch': 0.0}
# {'loss': 0.6931, 'grad_norm': 84.1331558227539, 'learning_rate': 1.0000000000000002e-06, 'rewards/chosen': 0.0, 'rewards/rejected': 0.0, 'rewards/accuracies': 0.0, 'rewards/margins': 0.0, 'logps/chosen': -448.68798828125, 'logps/rejected': -387.6080322265625, 'logits/chosen': 4.019976615905762, 'logits/rejected': 5.054856300354004, 'epoch': 0.0}
# {'loss': 0.7038, 'grad_norm': 93.25899505615234, 'learning_rate': 1.5e-06, 'rewards/chosen': -0.02288069762289524, 'rewards/rejected': -0.00739463372156024, 'rewards/accuracies': 0.4375, 'rewards/margins': -0.015486061573028564, 'logps/chosen': -632.8018798828125, 'logps/rejected': -477.3955993652344, 'logits/chosen': 3.6856465339660645, 'logits/rejected': 4.152348518371582, 'epoch': 0.0}
# {'loss': 0.6769, 'grad_norm': 62.63207244873047, 'learning_rate': 2.0000000000000003e-06, 'rewards/chosen': 0.0257547777146101, 'rewards/rejected': -0.008649695664644241, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.03440447151660919, 'logps/chosen': -264.941162109375, 'logps/rejected': -271.6332092285156, 'logits/chosen': 4.102177619934082, 'logits/rejected': 4.152557849884033, 'epoch': 0.0}
# {'loss': 0.7, 'grad_norm': 70.4498519897461, 'learning_rate': 2.5e-06, 'rewards/chosen': -0.0013344320468604565, 'rewards/rejected': 0.01083827018737793, 'rewards/accuracies': 0.4375, 'rewards/margins': -0.012172700837254524, 'logps/chosen': -311.5129089355469, 'logps/rejected': -255.53390502929688, 'logits/chosen': 3.2237796783447266, 'logits/rejected': 3.815427303314209, 'epoch': 0.0}
# {'loss': 0.6863, 'grad_norm': 62.00425720214844, 'learning_rate': 3e-06, 'rewards/chosen': 0.00012332946062088013, 'rewards/rejected': -0.014751355163753033, 'rewards/accuracies': 0.5, 'rewards/margins': 0.014874685555696487, 'logps/chosen': -295.1872863769531, 'logps/rejected': -222.0271453857422, 'logits/chosen': 3.9725077152252197, 'logits/rejected': 4.856944561004639, 'epoch': 0.0}
# {'loss': 0.6657, 'grad_norm': 88.3539810180664, 'learning_rate': 3.5000000000000004e-06, 'rewards/chosen': 0.05364484712481499, 'rewards/rejected': -0.005523358471691608, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.05916820466518402, 'logps/chosen': -544.217529296875, 'logps/rejected': -305.8409423828125, 'logits/chosen': 3.7233457565307617, 'logits/rejected': 2.633970022201538, 'epoch': 0.0}
# {'loss': 0.7119, 'grad_norm': 83.06559753417969, 'learning_rate': 4.000000000000001e-06, 'rewards/chosen': -0.03016800247132778, 'rewards/rejected': 0.002709275111556053, 'rewards/accuracies': 0.5, 'rewards/margins': -0.032877277582883835, 'logps/chosen': -454.73150634765625, 'logps/rejected': -347.0103454589844, 'logits/chosen': 3.3775994777679443, 'logits/rejected': 4.420052528381348, 'epoch': 0.0}
# {'loss': 0.7034, 'grad_norm': 83.21268463134766, 'learning_rate': 4.5e-06, 'rewards/chosen': -0.017262641340494156, 'rewards/rejected': 0.0009162239730358124, 'rewards/accuracies': 0.5, 'rewards/margins': -0.018178869038820267, 'logps/chosen': -418.00848388671875, 'logps/rejected': -418.44195556640625, 'logits/chosen': 3.509984254837036, 'logits/rejected': 3.445514440536499, 'epoch': 0.0}
# {'loss': 0.6952, 'grad_norm': 71.25923156738281, 'learning_rate': 5e-06, 'rewards/chosen': 0.0013667577877640724, 'rewards/rejected': 0.004643320105969906, 'rewards/accuracies': 0.5625, 'rewards/margins': -0.0032765616197139025, 'logps/chosen': -276.328125, 'logps/rejected': -340.4757080078125, 'logits/chosen': 4.400031089782715, 'logits/rejected': 4.057918071746826, 'epoch': 0.0}
# {'loss': 0.692, 'grad_norm': 79.49948120117188, 'learning_rate': 5.500000000000001e-06, 'rewards/chosen': 0.001285053789615631, 'rewards/rejected': -0.0038984804414212704, 'rewards/accuracies': 0.375, 'rewards/margins': 0.005183533299714327, 'logps/chosen': -407.9039306640625, 'logps/rejected': -340.9974670410156, 'logits/chosen': 3.9546685218811035, 'logits/rejected': 4.198294639587402, 'epoch': 0.0}
# {'loss': 0.6713, 'grad_norm': 89.45284271240234, 'learning_rate': 6e-06, 'rewards/chosen': 0.03150256723165512, 'rewards/rejected': -0.014620328322052956, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.046122897416353226, 'logps/chosen': -450.8056335449219, 'logps/rejected': -507.0924072265625, 'logits/chosen': 2.749537467956543, 'logits/rejected': 4.104183197021484, 'epoch': 0.0}
# {'loss': 0.6869, 'grad_norm': 92.81111145019531, 'learning_rate': 6.5000000000000004e-06, 'rewards/chosen': -0.008993328548967838, 'rewards/rejected': -0.022308219224214554, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.01331489160656929, 'logps/chosen': -489.1570739746094, 'logps/rejected': -449.4777526855469, 'logits/chosen': 5.257535934448242, 'logits/rejected': 4.213744163513184, 'epoch': 0.0}
# {'loss': 0.6931, 'grad_norm': 78.72586059570312, 'learning_rate': 7.000000000000001e-06, 'rewards/chosen': -0.000986514613032341, 'rewards/rejected': -0.003738068975508213, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.0027515534311532974, 'logps/chosen': -357.47735595703125, 'logps/rejected': -284.46844482421875, 'logits/chosen': 3.0782854557037354, 'logits/rejected': 4.4382243156433105, 'epoch': 0.0}
# {'loss': 0.7169, 'grad_norm': 79.04024505615234, 'learning_rate': 7.5e-06, 'rewards/chosen': -0.03740150108933449, 'rewards/rejected': 0.008380916900932789, 'rewards/accuracies': 0.25, 'rewards/margins': -0.0457824170589447, 'logps/chosen': -409.90496826171875, 'logps/rejected': -320.8099670410156, 'logits/chosen': 2.4495341777801514, 'logits/rejected': 2.6537373065948486, 'epoch': 0.0}
# {'loss': 0.6688, 'grad_norm': 87.53266906738281, 'learning_rate': 8.000000000000001e-06, 'rewards/chosen': 0.004430188797414303, 'rewards/rejected': -0.04624161124229431, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.05067180097103119, 'logps/chosen': -455.13336181640625, 'logps/rejected': -341.2382507324219, 'logits/chosen': 4.70344877243042, 'logits/rejected': 4.08238410949707, 'epoch': 0.0}
# {'loss': 0.7163, 'grad_norm': 80.92426300048828, 'learning_rate': 8.500000000000002e-06, 'rewards/chosen': -0.03178177773952484, 'rewards/rejected': 0.012784309685230255, 'rewards/accuracies': 0.1875, 'rewards/margins': -0.0445660836994648, 'logps/chosen': -441.3172912597656, 'logps/rejected': -391.1584167480469, 'logits/chosen': 1.990709662437439, 'logits/rejected': 2.71390962600708, 'epoch': 0.0}
# {'loss': 0.6881, 'grad_norm': 78.407958984375, 'learning_rate': 9e-06, 'rewards/chosen': -0.01338461134582758, 'rewards/rejected': -0.024580001831054688, 'rewards/accuracies': 0.5, 'rewards/margins': 0.011195391416549683, 'logps/chosen': -461.6923828125, 'logps/rejected': -329.0076599121094, 'logits/chosen': 2.8628411293029785, 'logits/rejected': 2.858459711074829, 'epoch': 0.0}
# {'loss': 0.6995, 'grad_norm': 80.44908905029297, 'learning_rate': 9.5e-06, 'rewards/chosen': -0.02727150171995163, 'rewards/rejected': -0.01874752901494503, 'rewards/accuracies': 0.375, 'rewards/margins': -0.008523971773684025, 'logps/chosen': -413.4571228027344, 'logps/rejected': -341.86981201171875, 'logits/chosen': 3.412531852722168, 'logits/rejected': 3.6735916137695312, 'epoch': 0.0}
# {'loss': 0.682, 'grad_norm': 69.86701202392578, 'learning_rate': 1e-05, 'rewards/chosen': -0.00880443211644888, 'rewards/rejected': -0.032570015639066696, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.02376558445394039, 'logps/chosen': -355.1253356933594, 'logps/rejected': -291.3941650390625, 'logits/chosen': 3.4357047080993652, 'logits/rejected': 3.898275375366211, 'epoch': 0.01}
# {'loss': 0.6808, 'grad_norm': 75.47916412353516, 'learning_rate': 1.05e-05, 'rewards/chosen': -9.121885523200035e-05, 'rewards/rejected': -0.027144944295287132, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.027053726837038994, 'logps/chosen': -436.3708190917969, 'logps/rejected': -374.13616943359375, 'logits/chosen': 4.345924377441406, 'logits/rejected': 4.122926712036133, 'epoch': 0.01}
# {'loss': 0.6957, 'grad_norm': 82.24227905273438, 'learning_rate': 1.1000000000000001e-05, 'rewards/chosen': -0.0013845786452293396, 'rewards/rejected': 0.002052652183920145, 'rewards/accuracies': 0.5, 'rewards/margins': -0.0034372303634881973, 'logps/chosen': -483.31396484375, 'logps/rejected': -401.01458740234375, 'logits/chosen': 4.466714859008789, 'logits/rejected': 3.820219039916992, 'epoch': 0.01}
# {'loss': 0.6988, 'grad_norm': 70.93103790283203, 'learning_rate': 1.1500000000000002e-05, 'rewards/chosen': -0.026609264314174652, 'rewards/rejected': -0.016370631754398346, 'rewards/accuracies': 0.4375, 'rewards/margins': -0.010238632559776306, 'logps/chosen': -249.80078125, 'logps/rejected': -278.1390380859375, 'logits/chosen': 3.6767663955688477, 'logits/rejected': 4.200091361999512, 'epoch': 0.01}
# {'loss': 0.6764, 'grad_norm': 73.1026840209961, 'learning_rate': 1.2e-05, 'rewards/chosen': 0.013090800493955612, 'rewards/rejected': -0.022908562794327736, 'rewards/accuracies': 0.625, 'rewards/margins': 0.0359993651509285, 'logps/chosen': -459.5582275390625, 'logps/rejected': -417.4631042480469, 'logits/chosen': 3.1954967975616455, 'logits/rejected': 3.1197292804718018, 'epoch': 0.01}
# {'loss': 0.668, 'grad_norm': 62.69466018676758, 'learning_rate': 1.25e-05, 'rewards/chosen': 0.004930245690047741, 'rewards/rejected': -0.05029379203915596, 'rewards/accuracies': 0.4375, 'rewards/margins': 0.055224038660526276, 'logps/chosen': -427.1322937011719, 'logps/rejected': -236.94033813476562, 'logits/chosen': 3.0427730083465576, 'logits/rejected': 3.013197422027588, 'epoch': 0.01}
# {'loss': 0.6883, 'grad_norm': 71.33036041259766, 'learning_rate': 1.3000000000000001e-05, 'rewards/chosen': -0.008369178511202335, 'rewards/rejected': -0.019266372546553612, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.010897191241383553, 'logps/chosen': -329.1458740234375, 'logps/rejected': -223.0716094970703, 'logits/chosen': 4.327306747436523, 'logits/rejected': 3.9707727432250977, 'epoch': 0.01}
# {'loss': 0.6772, 'grad_norm': 75.84259796142578, 'learning_rate': 1.3500000000000001e-05, 'rewards/chosen': -0.007589737884700298, 'rewards/rejected': -0.04151977598667145, 'rewards/accuracies': 0.5, 'rewards/margins': 0.033930037170648575, 'logps/chosen': -344.2580261230469, 'logps/rejected': -303.90325927734375, 'logits/chosen': 4.1806640625, 'logits/rejected': 4.351552963256836, 'epoch': 0.01}
# {'loss': 0.6806, 'grad_norm': 76.12300872802734, 'learning_rate': 1.4000000000000001e-05, 'rewards/chosen': 0.013064319267868996, 'rewards/rejected': -0.019374419003725052, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.0324387364089489, 'logps/chosen': -313.12689208984375, 'logps/rejected': -426.17779541015625, 'logits/chosen': 2.801690101623535, 'logits/rejected': 3.8353066444396973, 'epoch': 0.01}
# {'loss': 0.6697, 'grad_norm': 95.24771118164062, 'learning_rate': 1.45e-05, 'rewards/chosen': -0.03416261821985245, 'rewards/rejected': -0.08887247741222382, 'rewards/accuracies': 0.625, 'rewards/margins': 0.05470985919237137, 'logps/chosen': -580.760498046875, 'logps/rejected': -480.8699035644531, 'logits/chosen': 3.3682944774627686, 'logits/rejected': 2.9075305461883545, 'epoch': 0.01}
# {'loss': 0.6866, 'grad_norm': 65.24618530273438, 'learning_rate': 1.5e-05, 'rewards/chosen': -0.03486187383532524, 'rewards/rejected': -0.05180729180574417, 'rewards/accuracies': 0.625, 'rewards/margins': 0.01694541610777378, 'logps/chosen': -322.78753662109375, 'logps/rejected': -242.98065185546875, 'logits/chosen': 3.228633403778076, 'logits/rejected': 2.642300605773926, 'epoch': 0.01}
# {'loss': 0.6899, 'grad_norm': 91.49640655517578, 'learning_rate': 1.55e-05, 'rewards/chosen': -0.07092531025409698, 'rewards/rejected': -0.08099739253520966, 'rewards/accuracies': 0.5, 'rewards/margins': 0.010072087869048119, 'logps/chosen': -513.08349609375, 'logps/rejected': -427.48187255859375, 'logits/chosen': 4.622862815856934, 'logits/rejected': 3.904834270477295, 'epoch': 0.01}
# {'loss': 0.6845, 'grad_norm': 60.311370849609375, 'learning_rate': 1.6000000000000003e-05, 'rewards/chosen': -0.016793377697467804, 'rewards/rejected': -0.03653895854949951, 'rewards/accuracies': 0.5, 'rewards/margins': 0.019745584577322006, 'logps/chosen': -248.80490112304688, 'logps/rejected': -187.0494384765625, 'logits/chosen': 4.38729190826416, 'logits/rejected': 4.396641254425049, 'epoch': 0.01}
# {'loss': 0.6906, 'grad_norm': 71.09090423583984, 'learning_rate': 1.65e-05, 'rewards/chosen': -0.04327259212732315, 'rewards/rejected': -0.050232261419296265, 'rewards/accuracies': 0.5, 'rewards/margins': 0.006959670223295689, 'logps/chosen': -293.7052001953125, 'logps/rejected': -264.02740478515625, 'logits/chosen': 3.123274803161621, 'logits/rejected': 4.750657081604004, 'epoch': 0.01}
# {'loss': 0.7097, 'grad_norm': 79.17552947998047, 'learning_rate': 1.7000000000000003e-05, 'rewards/chosen': -0.05316155403852463, 'rewards/rejected': -0.024319469928741455, 'rewards/accuracies': 0.25, 'rewards/margins': -0.028842080384492874, 'logps/chosen': -473.48016357421875, 'logps/rejected': -397.8642272949219, 'logits/chosen': 3.222961187362671, 'logits/rejected': 2.67333722114563, 'epoch': 0.01}
# {'loss': 0.6663, 'grad_norm': 64.293701171875, 'learning_rate': 1.75e-05, 'rewards/chosen': -0.032821401953697205, 'rewards/rejected': -0.09063364565372467, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.057812243700027466, 'logps/chosen': -300.9527587890625, 'logps/rejected': -292.15234375, 'logits/chosen': 2.5848941802978516, 'logits/rejected': 2.525982618331909, 'epoch': 0.01}
# {'loss': 0.6678, 'grad_norm': 78.41094207763672, 'learning_rate': 1.8e-05, 'rewards/chosen': -0.047755755484104156, 'rewards/rejected': -0.11014574021100998, 'rewards/accuracies': 0.625, 'rewards/margins': 0.062389977276325226, 'logps/chosen': -494.68243408203125, 'logps/rejected': -304.3135070800781, 'logits/chosen': 3.452568769454956, 'logits/rejected': 4.011838436126709, 'epoch': 0.01}
# {'loss': 0.6973, 'grad_norm': 86.45574951171875, 'learning_rate': 1.85e-05, 'rewards/chosen': -0.0867069736123085, 'rewards/rejected': -0.08412964642047882, 'rewards/accuracies': 0.5625, 'rewards/margins': -0.00257733091711998, 'logps/chosen': -445.96759033203125, 'logps/rejected': -435.1806640625, 'logits/chosen': 3.3447787761688232, 'logits/rejected': 2.873135566711426, 'epoch': 0.01}
# {'loss': 0.654, 'grad_norm': 71.46704864501953, 'learning_rate': 1.9e-05, 'rewards/chosen': -0.0052514029666781425, 'rewards/rejected': -0.0957326591014862, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.09048125892877579, 'logps/chosen': -325.6404113769531, 'logps/rejected': -372.2637939453125, 'logits/chosen': 3.6883373260498047, 'logits/rejected': 4.407192230224609, 'epoch': 0.01}
# {'loss': 0.6522, 'grad_norm': 88.54658508300781, 'learning_rate': 1.9500000000000003e-05, 'rewards/chosen': -0.00223474926315248, 'rewards/rejected': -0.093637615442276, 'rewards/accuracies': 0.75, 'rewards/margins': 0.09140285104513168, 'logps/chosen': -629.8279418945312, 'logps/rejected': -453.6080017089844, 'logits/chosen': 3.6126198768615723, 'logits/rejected': 3.0564353466033936, 'epoch': 0.01}
# {'loss': 0.6914, 'grad_norm': 70.77767181396484, 'learning_rate': 2e-05, 'rewards/chosen': -0.09900779277086258, 'rewards/rejected': -0.11605070531368256, 'rewards/accuracies': 0.5, 'rewards/margins': 0.017042914405465126, 'logps/chosen': -316.8402099609375, 'logps/rejected': -368.8804931640625, 'logits/chosen': 3.6627886295318604, 'logits/rejected': 4.326141357421875, 'epoch': 0.01}
# {'loss': 0.6444, 'grad_norm': 71.7891845703125, 'learning_rate': 2.05e-05, 'rewards/chosen': -0.02543690800666809, 'rewards/rejected': -0.13512875139713287, 'rewards/accuracies': 0.625, 'rewards/margins': 0.10969182848930359, 'logps/chosen': -504.6124267578125, 'logps/rejected': -370.7712707519531, 'logits/chosen': 3.230078935623169, 'logits/rejected': 4.012853622436523, 'epoch': 0.01}
# {'loss': 0.7303, 'grad_norm': 86.52265930175781, 'learning_rate': 2.1e-05, 'rewards/chosen': -0.13939687609672546, 'rewards/rejected': -0.08419317752122879, 'rewards/accuracies': 0.4375, 'rewards/margins': -0.05520370230078697, 'logps/chosen': -388.6465148925781, 'logps/rejected': -407.7218933105469, 'logits/chosen': 4.803760528564453, 'logits/rejected': 4.050617694854736, 'epoch': 0.01}
# {'loss': 0.6204, 'grad_norm': 82.6333999633789, 'learning_rate': 2.15e-05, 'rewards/chosen': -0.051549434661865234, 'rewards/rejected': -0.2276334911584854, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.17608404159545898, 'logps/chosen': -527.1053466796875, 'logps/rejected': -455.4649963378906, 'logits/chosen': 2.746039628982544, 'logits/rejected': 3.8782191276550293, 'epoch': 0.01}
# {'loss': 0.7362, 'grad_norm': 68.73967742919922, 'learning_rate': 2.2000000000000003e-05, 'rewards/chosen': -0.123545803129673, 'rewards/rejected': -0.05212999880313873, 'rewards/accuracies': 0.4375, 'rewards/margins': -0.07141581177711487, 'logps/chosen': -252.73495483398438, 'logps/rejected': -242.32171630859375, 'logits/chosen': 4.594643592834473, 'logits/rejected': 3.7582175731658936, 'epoch': 0.01}
# {'loss': 0.63, 'grad_norm': 80.8443374633789, 'learning_rate': 2.25e-05, 'rewards/chosen': 0.024041080847382545, 'rewards/rejected': -0.12275930494070053, 'rewards/accuracies': 0.75, 'rewards/margins': 0.14680039882659912, 'logps/chosen': -637.0142211914062, 'logps/rejected': -425.96966552734375, 'logits/chosen': 3.3561062812805176, 'logits/rejected': 3.574148178100586, 'epoch': 0.01}
# {'loss': 0.6363, 'grad_norm': 76.412841796875, 'learning_rate': 2.3000000000000003e-05, 'rewards/chosen': 0.01392270252108574, 'rewards/rejected': -0.13477234542369843, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.14869503676891327, 'logps/chosen': -471.70263671875, 'logps/rejected': -334.5609130859375, 'logits/chosen': 2.9276111125946045, 'logits/rejected': 1.882434606552124, 'epoch': 0.01}
# {'loss': 0.6357, 'grad_norm': 70.49998474121094, 'learning_rate': 2.35e-05, 'rewards/chosen': -0.07971620559692383, 'rewards/rejected': -0.22850370407104492, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.1487874984741211, 'logps/chosen': -396.13446044921875, 'logps/rejected': -399.9769287109375, 'logits/chosen': 3.7589709758758545, 'logits/rejected': 3.7062220573425293, 'epoch': 0.01}
# {'loss': 0.6253, 'grad_norm': 65.64270782470703, 'learning_rate': 2.4e-05, 'rewards/chosen': -0.00993187353014946, 'rewards/rejected': -0.16327376663684845, 'rewards/accuracies': 0.75, 'rewards/margins': 0.1533418893814087, 'logps/chosen': -375.257568359375, 'logps/rejected': -263.2237243652344, 'logits/chosen': 4.830514430999756, 'logits/rejected': 4.804205894470215, 'epoch': 0.01}
# {'loss': 0.6097, 'grad_norm': 75.68550872802734, 'learning_rate': 2.45e-05, 'rewards/chosen': -0.06676533818244934, 'rewards/rejected': -0.3020149767398834, 'rewards/accuracies': 0.625, 'rewards/margins': 0.23524963855743408, 'logps/chosen': -565.5540771484375, 'logps/rejected': -490.94537353515625, 'logits/chosen': 3.6350576877593994, 'logits/rejected': 4.1338653564453125, 'epoch': 0.01}
# {'loss': 0.5842, 'grad_norm': 67.4321060180664, 'learning_rate': 2.5e-05, 'rewards/chosen': 0.022862469777464867, 'rewards/rejected': -0.22313787043094635, 'rewards/accuracies': 0.9375, 'rewards/margins': 0.24600036442279816, 'logps/chosen': -388.0316467285156, 'logps/rejected': -360.24542236328125, 'logits/chosen': 3.8864665031433105, 'logits/rejected': 4.1599555015563965, 'epoch': 0.01}
# {'loss': 0.6359, 'grad_norm': 68.56449127197266, 'learning_rate': 2.5500000000000003e-05, 'rewards/chosen': -0.09146897494792938, 'rewards/rejected': -0.2222929298877716, 'rewards/accuracies': 0.75, 'rewards/margins': 0.13082395493984222, 'logps/chosen': -381.980712890625, 'logps/rejected': -315.6024169921875, 'logits/chosen': 2.1269052028656006, 'logits/rejected': 2.107233762741089, 'epoch': 0.01}
# {'loss': 0.6937, 'grad_norm': 72.22064208984375, 'learning_rate': 2.6000000000000002e-05, 'rewards/chosen': -0.09787863492965698, 'rewards/rejected': -0.12888871133327484, 'rewards/accuracies': 0.625, 'rewards/margins': 0.031010061502456665, 'logps/chosen': -433.97930908203125, 'logps/rejected': -331.27880859375, 'logits/chosen': 3.534517288208008, 'logits/rejected': 3.2131426334381104, 'epoch': 0.01}
# {'loss': 0.7283, 'grad_norm': 87.79106140136719, 'learning_rate': 2.6500000000000004e-05, 'rewards/chosen': -0.10619223117828369, 'rewards/rejected': -0.0857846587896347, 'rewards/accuracies': 0.5625, 'rewards/margins': -0.02040756866335869, 'logps/chosen': -388.25653076171875, 'logps/rejected': -443.2334899902344, 'logits/chosen': 3.061929702758789, 'logits/rejected': 3.8217978477478027, 'epoch': 0.01}
# {'loss': 0.7576, 'grad_norm': 83.66556549072266, 'learning_rate': 2.7000000000000002e-05, 'rewards/chosen': -0.35818514227867126, 'rewards/rejected': -0.2849322557449341, 'rewards/accuracies': 0.5625, 'rewards/margins': -0.0732528567314148, 'logps/chosen': -410.7882080078125, 'logps/rejected': -297.94207763671875, 'logits/chosen': 3.2853362560272217, 'logits/rejected': 4.210265159606934, 'epoch': 0.01}
# {'loss': 0.7738, 'grad_norm': 122.6889419555664, 'learning_rate': 2.7500000000000004e-05, 'rewards/chosen': -0.3237503170967102, 'rewards/rejected': -0.27666258811950684, 'rewards/accuracies': 0.5, 'rewards/margins': -0.047087736427783966, 'logps/chosen': -519.9589233398438, 'logps/rejected': -470.3544616699219, 'logits/chosen': 4.138704776763916, 'logits/rejected': 5.269287109375, 'epoch': 0.01}
# {'loss': 0.7368, 'grad_norm': 80.72666931152344, 'learning_rate': 2.8000000000000003e-05, 'rewards/chosen': -0.10219234973192215, 'rewards/rejected': -0.08437233418226242, 'rewards/accuracies': 0.5625, 'rewards/margins': -0.01782001554965973, 'logps/chosen': -324.64892578125, 'logps/rejected': -275.525634765625, 'logits/chosen': 4.094155311584473, 'logits/rejected': 4.56770658493042, 'epoch': 0.01}
# {'loss': 0.55, 'grad_norm': 66.31117248535156, 'learning_rate': 2.8499999999999998e-05, 'rewards/chosen': -0.0813443660736084, 'rewards/rejected': -0.4901201128959656, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.40877580642700195, 'logps/chosen': -282.0029296875, 'logps/rejected': -426.6395263671875, 'logits/chosen': 4.624945163726807, 'logits/rejected': 3.930720806121826, 'epoch': 0.01}
# {'loss': 0.57, 'grad_norm': 66.93904876708984, 'learning_rate': 2.9e-05, 'rewards/chosen': -0.010637648403644562, 'rewards/rejected': -0.312924861907959, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.3022872507572174, 'logps/chosen': -443.3410949707031, 'logps/rejected': -262.9799499511719, 'logits/chosen': 3.543203830718994, 'logits/rejected': 2.986403465270996, 'epoch': 0.01}
# {'loss': 0.7098, 'grad_norm': 71.03028106689453, 'learning_rate': 2.95e-05, 'rewards/chosen': -0.2802858352661133, 'rewards/rejected': -0.2891892194747925, 'rewards/accuracies': 0.375, 'rewards/margins': 0.00890342891216278, 'logps/chosen': -374.5328369140625, 'logps/rejected': -389.40032958984375, 'logits/chosen': 3.534520149230957, 'logits/rejected': 3.3189239501953125, 'epoch': 0.02}
# {'loss': 0.6553, 'grad_norm': 70.52047729492188, 'learning_rate': 3e-05, 'rewards/chosen': -0.3215307593345642, 'rewards/rejected': -0.45702388882637024, 'rewards/accuracies': 0.75, 'rewards/margins': 0.13549309968948364, 'logps/chosen': -373.583251953125, 'logps/rejected': -296.05975341796875, 'logits/chosen': 3.697493553161621, 'logits/rejected': 3.7571821212768555, 'epoch': 0.02}
# {'loss': 0.614, 'grad_norm': 63.435462951660156, 'learning_rate': 3.05e-05, 'rewards/chosen': -0.15012623369693756, 'rewards/rejected': -0.39227965474128723, 'rewards/accuracies': 0.625, 'rewards/margins': 0.24215340614318848, 'logps/chosen': -340.0548400878906, 'logps/rejected': -306.2102966308594, 'logits/chosen': 2.9015462398529053, 'logits/rejected': 2.6932313442230225, 'epoch': 0.02}
# {'loss': 0.6801, 'grad_norm': 67.79254150390625, 'learning_rate': 3.1e-05, 'rewards/chosen': -0.15512463450431824, 'rewards/rejected': -0.28998368978500366, 'rewards/accuracies': 0.4375, 'rewards/margins': 0.1348590850830078, 'logps/chosen': -442.37017822265625, 'logps/rejected': -316.29541015625, 'logits/chosen': 4.405675888061523, 'logits/rejected': 3.736745834350586, 'epoch': 0.02}
# {'loss': 0.651, 'grad_norm': 101.33091735839844, 'learning_rate': 3.15e-05, 'rewards/chosen': -0.4205642640590668, 'rewards/rejected': -0.6590102910995483, 'rewards/accuracies': 0.625, 'rewards/margins': 0.23844601213932037, 'logps/chosen': -492.403564453125, 'logps/rejected': -356.08807373046875, 'logits/chosen': 3.082423448562622, 'logits/rejected': 3.3344192504882812, 'epoch': 0.02}
# {'loss': 0.6151, 'grad_norm': 79.7384262084961, 'learning_rate': 3.2000000000000005e-05, 'rewards/chosen': -0.12797462940216064, 'rewards/rejected': -0.33552035689353943, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.20754572749137878, 'logps/chosen': -435.60382080078125, 'logps/rejected': -383.78668212890625, 'logits/chosen': 3.8311948776245117, 'logits/rejected': 3.919032335281372, 'epoch': 0.02}
# {'loss': 0.75, 'grad_norm': 74.7136001586914, 'learning_rate': 3.2500000000000004e-05, 'rewards/chosen': -0.22663797438144684, 'rewards/rejected': -0.19315539300441742, 'rewards/accuracies': 0.5625, 'rewards/margins': -0.033482566475868225, 'logps/chosen': -254.1479034423828, 'logps/rejected': -325.4417724609375, 'logits/chosen': 3.0640647411346436, 'logits/rejected': 2.950754165649414, 'epoch': 0.02}
# {'loss': 0.6905, 'grad_norm': 74.01056671142578, 'learning_rate': 3.3e-05, 'rewards/chosen': -0.3906981945037842, 'rewards/rejected': -0.4304565489292145, 'rewards/accuracies': 0.5, 'rewards/margins': 0.039758361876010895, 'logps/chosen': -354.7919921875, 'logps/rejected': -213.2152862548828, 'logits/chosen': 3.604142427444458, 'logits/rejected': 3.484459400177002, 'epoch': 0.02}
# {'loss': 0.5762, 'grad_norm': 75.18159484863281, 'learning_rate': 3.35e-05, 'rewards/chosen': -0.31619954109191895, 'rewards/rejected': -0.6297631859779358, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.31356364488601685, 'logps/chosen': -520.4595947265625, 'logps/rejected': -404.1552429199219, 'logits/chosen': 3.708726167678833, 'logits/rejected': 3.3178677558898926, 'epoch': 0.02}
# {'loss': 0.6982, 'grad_norm': 92.52705383300781, 'learning_rate': 3.4000000000000007e-05, 'rewards/chosen': -0.35788798332214355, 'rewards/rejected': -0.39176371693611145, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.033875755965709686, 'logps/chosen': -522.82080078125, 'logps/rejected': -445.0193176269531, 'logits/chosen': 3.0435824394226074, 'logits/rejected': 3.6489415168762207, 'epoch': 0.02}
# {'loss': 0.675, 'grad_norm': 91.1403579711914, 'learning_rate': 3.45e-05, 'rewards/chosen': -0.23713821172714233, 'rewards/rejected': -0.46473729610443115, 'rewards/accuracies': 0.625, 'rewards/margins': 0.22759906947612762, 'logps/chosen': -518.4332275390625, 'logps/rejected': -409.5169372558594, 'logits/chosen': 3.6065280437469482, 'logits/rejected': 3.1375529766082764, 'epoch': 0.02}
# {'loss': 0.6233, 'grad_norm': 95.84953308105469, 'learning_rate': 3.5e-05, 'rewards/chosen': -0.4214714765548706, 'rewards/rejected': -0.643297553062439, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.22182607650756836, 'logps/chosen': -514.2335205078125, 'logps/rejected': -460.2022705078125, 'logits/chosen': 2.77848482131958, 'logits/rejected': 3.434558868408203, 'epoch': 0.02}
# {'loss': 0.6337, 'grad_norm': 69.00934600830078, 'learning_rate': 3.55e-05, 'rewards/chosen': -0.1451975554227829, 'rewards/rejected': -0.40551087260246277, 'rewards/accuracies': 0.5, 'rewards/margins': 0.2603133022785187, 'logps/chosen': -398.1741027832031, 'logps/rejected': -346.54449462890625, 'logits/chosen': 2.966104745864868, 'logits/rejected': 3.7952139377593994, 'epoch': 0.02}
# {'loss': 0.6894, 'grad_norm': 89.61278533935547, 'learning_rate': 3.6e-05, 'rewards/chosen': -0.325284481048584, 'rewards/rejected': -0.45369434356689453, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.12840986251831055, 'logps/chosen': -545.4429321289062, 'logps/rejected': -447.34405517578125, 'logits/chosen': 3.8958401679992676, 'logits/rejected': 3.8687961101531982, 'epoch': 0.02}
# {'loss': 0.5564, 'grad_norm': 84.0965805053711, 'learning_rate': 3.65e-05, 'rewards/chosen': -0.4405710995197296, 'rewards/rejected': -0.8556218147277832, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.4150506854057312, 'logps/chosen': -617.14697265625, 'logps/rejected': -464.677734375, 'logits/chosen': 3.370246410369873, 'logits/rejected': 2.8179781436920166, 'epoch': 0.02}
# {'loss': 0.7036, 'grad_norm': 93.55171966552734, 'learning_rate': 3.7e-05, 'rewards/chosen': -0.569574236869812, 'rewards/rejected': -0.7132779359817505, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.14370374381542206, 'logps/chosen': -517.2701416015625, 'logps/rejected': -346.8185119628906, 'logits/chosen': 1.9218885898590088, 'logits/rejected': 1.6982245445251465, 'epoch': 0.02}
# {'loss': 0.6955, 'grad_norm': 71.91248321533203, 'learning_rate': 3.7500000000000003e-05, 'rewards/chosen': -0.2834806442260742, 'rewards/rejected': -0.368133008480072, 'rewards/accuracies': 0.4375, 'rewards/margins': 0.08465233445167542, 'logps/chosen': -436.49481201171875, 'logps/rejected': -273.848876953125, 'logits/chosen': 3.626617908477783, 'logits/rejected': 2.6365272998809814, 'epoch': 0.02}
# {'loss': 0.5918, 'grad_norm': 83.64225769042969, 'learning_rate': 3.8e-05, 'rewards/chosen': -0.3142932057380676, 'rewards/rejected': -0.6331878900527954, 'rewards/accuracies': 0.75, 'rewards/margins': 0.3188946545124054, 'logps/chosen': -590.78271484375, 'logps/rejected': -579.560546875, 'logits/chosen': 2.459038734436035, 'logits/rejected': 3.767228126525879, 'epoch': 0.02}
# {'loss': 0.5724, 'grad_norm': 70.20320129394531, 'learning_rate': 3.85e-05, 'rewards/chosen': -0.16477032005786896, 'rewards/rejected': -0.5139651298522949, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.34919479489326477, 'logps/chosen': -476.70263671875, 'logps/rejected': -443.56439208984375, 'logits/chosen': 3.632554054260254, 'logits/rejected': 3.077056884765625, 'epoch': 0.02}
# {'loss': 0.5515, 'grad_norm': 66.24382781982422, 'learning_rate': 3.9000000000000006e-05, 'rewards/chosen': -0.2625228762626648, 'rewards/rejected': -0.6997004747390747, 'rewards/accuracies': 0.625, 'rewards/margins': 0.4371775984764099, 'logps/chosen': -590.9732055664062, 'logps/rejected': -388.686279296875, 'logits/chosen': 4.3401923179626465, 'logits/rejected': 2.647853374481201, 'epoch': 0.02}
# {'loss': 0.5141, 'grad_norm': 68.98358917236328, 'learning_rate': 3.9500000000000005e-05, 'rewards/chosen': -0.25377708673477173, 'rewards/rejected': -0.7254608869552612, 'rewards/accuracies': 0.9375, 'rewards/margins': 0.4716837704181671, 'logps/chosen': -504.6466369628906, 'logps/rejected': -479.56512451171875, 'logits/chosen': 3.7841367721557617, 'logits/rejected': 4.7529449462890625, 'epoch': 0.02}
# {'loss': 0.729, 'grad_norm': 103.17302703857422, 'learning_rate': 4e-05, 'rewards/chosen': -0.5306177139282227, 'rewards/rejected': -0.5912299156188965, 'rewards/accuracies': 0.625, 'rewards/margins': 0.060612212866544724, 'logps/chosen': -544.3675537109375, 'logps/rejected': -615.4032592773438, 'logits/chosen': 2.596355438232422, 'logits/rejected': 3.121420383453369, 'epoch': 0.02}
# {'loss': 0.8207, 'grad_norm': 100.23770904541016, 'learning_rate': 4.05e-05, 'rewards/chosen': -0.7011252641677856, 'rewards/rejected': -0.5879802107810974, 'rewards/accuracies': 0.5, 'rewards/margins': -0.11314508318901062, 'logps/chosen': -471.9314270019531, 'logps/rejected': -554.4611206054688, 'logits/chosen': 1.8042826652526855, 'logits/rejected': 2.404947280883789, 'epoch': 0.02}
# {'loss': 0.7183, 'grad_norm': 81.83245849609375, 'learning_rate': 4.1e-05, 'rewards/chosen': -0.5111573338508606, 'rewards/rejected': -0.5800727605819702, 'rewards/accuracies': 0.5, 'rewards/margins': 0.0689154714345932, 'logps/chosen': -277.754638671875, 'logps/rejected': -316.64605712890625, 'logits/chosen': 3.565521240234375, 'logits/rejected': 3.1589109897613525, 'epoch': 0.02}
# {'loss': 0.9497, 'grad_norm': 110.23067474365234, 'learning_rate': 4.15e-05, 'rewards/chosen': -0.7564394474029541, 'rewards/rejected': -0.6547020077705383, 'rewards/accuracies': 0.5625, 'rewards/margins': -0.10173749923706055, 'logps/chosen': -468.19720458984375, 'logps/rejected': -363.0418701171875, 'logits/chosen': 2.3479113578796387, 'logits/rejected': 2.454324722290039, 'epoch': 0.02}
# {'loss': 0.7284, 'grad_norm': 92.4112777709961, 'learning_rate': 4.2e-05, 'rewards/chosen': -0.48601239919662476, 'rewards/rejected': -0.5810956954956055, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.09508328139781952, 'logps/chosen': -437.0209045410156, 'logps/rejected': -481.49688720703125, 'logits/chosen': 2.758300304412842, 'logits/rejected': 2.8684539794921875, 'epoch': 0.02}
# {'loss': 0.6164, 'grad_norm': 75.87166595458984, 'learning_rate': 4.25e-05, 'rewards/chosen': -0.41331392526626587, 'rewards/rejected': -0.657885730266571, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.24457184970378876, 'logps/chosen': -483.9731140136719, 'logps/rejected': -350.98345947265625, 'logits/chosen': 2.7278850078582764, 'logits/rejected': 3.5928189754486084, 'epoch': 0.02}
# {'loss': 0.7149, 'grad_norm': 81.45235443115234, 'learning_rate': 4.3e-05, 'rewards/chosen': -0.6233465671539307, 'rewards/rejected': -0.778295636177063, 'rewards/accuracies': 0.625, 'rewards/margins': 0.1549491435289383, 'logps/chosen': -333.49090576171875, 'logps/rejected': -340.17864990234375, 'logits/chosen': 2.538395643234253, 'logits/rejected': 3.345055103302002, 'epoch': 0.02}
# {'loss': 0.4872, 'grad_norm': 52.5638427734375, 'learning_rate': 4.35e-05, 'rewards/chosen': -0.3944350481033325, 'rewards/rejected': -1.0913338661193848, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.696898877620697, 'logps/chosen': -273.42755126953125, 'logps/rejected': -371.24273681640625, 'logits/chosen': 2.500748872756958, 'logits/rejected': 3.2628087997436523, 'epoch': 0.02}
# {'loss': 0.7391, 'grad_norm': 84.27344512939453, 'learning_rate': 4.4000000000000006e-05, 'rewards/chosen': -0.4866749048233032, 'rewards/rejected': -0.49002042412757874, 'rewards/accuracies': 0.375, 'rewards/margins': 0.003345498815178871, 'logps/chosen': -439.43817138671875, 'logps/rejected': -323.46978759765625, 'logits/chosen': 3.3899118900299072, 'logits/rejected': 4.254508972167969, 'epoch': 0.02}
# {'loss': 0.7133, 'grad_norm': 81.79051971435547, 'learning_rate': 4.4500000000000004e-05, 'rewards/chosen': -0.6704211235046387, 'rewards/rejected': -0.8979337811470032, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.2275126576423645, 'logps/chosen': -493.6296691894531, 'logps/rejected': -398.31195068359375, 'logits/chosen': 2.2117958068847656, 'logits/rejected': 3.158423900604248, 'epoch': 0.02}
# {'loss': 0.6844, 'grad_norm': 71.57011413574219, 'learning_rate': 4.5e-05, 'rewards/chosen': -0.6303489208221436, 'rewards/rejected': -0.8471736907958984, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.2168247103691101, 'logps/chosen': -513.3817749023438, 'logps/rejected': -345.00286865234375, 'logits/chosen': 2.1649603843688965, 'logits/rejected': 1.9152748584747314, 'epoch': 0.02}
# {'loss': 0.6866, 'grad_norm': 86.6971206665039, 'learning_rate': 4.55e-05, 'rewards/chosen': -0.5468764901161194, 'rewards/rejected': -0.6433556079864502, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.09647903591394424, 'logps/chosen': -428.3685302734375, 'logps/rejected': -384.9872131347656, 'logits/chosen': 3.5703213214874268, 'logits/rejected': 3.8693642616271973, 'epoch': 0.02}
# {'loss': 0.6132, 'grad_norm': 80.54158020019531, 'learning_rate': 4.600000000000001e-05, 'rewards/chosen': -0.6231580376625061, 'rewards/rejected': -0.9332866072654724, 'rewards/accuracies': 0.75, 'rewards/margins': 0.3101285696029663, 'logps/chosen': -628.1527099609375, 'logps/rejected': -414.9220275878906, 'logits/chosen': 2.7898759841918945, 'logits/rejected': 2.4373793601989746, 'epoch': 0.02}
# {'loss': 0.5805, 'grad_norm': 60.84787368774414, 'learning_rate': 4.6500000000000005e-05, 'rewards/chosen': -0.3575812578201294, 'rewards/rejected': -0.6698434948921204, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.3122621774673462, 'logps/chosen': -382.896240234375, 'logps/rejected': -314.09368896484375, 'logits/chosen': 4.328310012817383, 'logits/rejected': 3.2066898345947266, 'epoch': 0.02}
# {'loss': 0.6812, 'grad_norm': 79.44579315185547, 'learning_rate': 4.7e-05, 'rewards/chosen': -0.5833641290664673, 'rewards/rejected': -0.8152540922164917, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.23188990354537964, 'logps/chosen': -396.7052001953125, 'logps/rejected': -373.81781005859375, 'logits/chosen': 3.7143161296844482, 'logits/rejected': 4.119771480560303, 'epoch': 0.02}
# {'loss': 0.4959, 'grad_norm': 70.82467651367188, 'learning_rate': 4.75e-05, 'rewards/chosen': -0.43662014603614807, 'rewards/rejected': -1.0059932470321655, 'rewards/accuracies': 0.875, 'rewards/margins': 0.5693731307983398, 'logps/chosen': -487.1795349121094, 'logps/rejected': -370.4237060546875, 'logits/chosen': 2.3698976039886475, 'logits/rejected': 2.634457588195801, 'epoch': 0.02}
# {'loss': 0.5688, 'grad_norm': 86.03861999511719, 'learning_rate': 4.8e-05, 'rewards/chosen': -0.5223673582077026, 'rewards/rejected': -1.109483003616333, 'rewards/accuracies': 0.625, 'rewards/margins': 0.5871155858039856, 'logps/chosen': -459.1461181640625, 'logps/rejected': -577.2757568359375, 'logits/chosen': 3.3295116424560547, 'logits/rejected': 3.631648540496826, 'epoch': 0.02}
# {'loss': 0.7523, 'grad_norm': 70.12358856201172, 'learning_rate': 4.85e-05, 'rewards/chosen': -0.6348782181739807, 'rewards/rejected': -0.6229622960090637, 'rewards/accuracies': 0.5, 'rewards/margins': -0.011915922164916992, 'logps/chosen': -380.69384765625, 'logps/rejected': -252.53402709960938, 'logits/chosen': 3.1948843002319336, 'logits/rejected': 3.4586596488952637, 'epoch': 0.02}
# {'loss': 0.5059, 'grad_norm': 62.35122299194336, 'learning_rate': 4.9e-05, 'rewards/chosen': -0.2790463864803314, 'rewards/rejected': -0.8255350589752197, 'rewards/accuracies': 0.75, 'rewards/margins': 0.5464886426925659, 'logps/chosen': -431.0236511230469, 'logps/rejected': -267.70025634765625, 'logits/chosen': 2.3115220069885254, 'logits/rejected': 3.4971070289611816, 'epoch': 0.03}
# {'loss': 0.6122, 'grad_norm': 84.67599487304688, 'learning_rate': 4.9500000000000004e-05, 'rewards/chosen': -0.44181180000305176, 'rewards/rejected': -0.965865433216095, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.524053692817688, 'logps/chosen': -667.2314453125, 'logps/rejected': -704.703369140625, 'logits/chosen': 2.8105783462524414, 'logits/rejected': 3.761216878890991, 'epoch': 0.03}
# {'loss': 0.5892, 'grad_norm': 65.02376556396484, 'learning_rate': 5e-05, 'rewards/chosen': -0.5270910263061523, 'rewards/rejected': -0.8357269763946533, 'rewards/accuracies': 0.75, 'rewards/margins': 0.308635950088501, 'logps/chosen': -329.8823547363281, 'logps/rejected': -236.1243896484375, 'logits/chosen': 2.6577277183532715, 'logits/rejected': 1.5961241722106934, 'epoch': 0.03}
# {'loss': 0.5552, 'grad_norm': 65.24833679199219, 'learning_rate': 4.998766400914329e-05, 'rewards/chosen': -0.6601406335830688, 'rewards/rejected': -1.0589442253112793, 'rewards/accuracies': 0.75, 'rewards/margins': 0.3988037109375, 'logps/chosen': -450.38818359375, 'logps/rejected': -374.1773681640625, 'logits/chosen': 3.1067702770233154, 'logits/rejected': 3.6408915519714355, 'epoch': 0.03}
# {'loss': 0.7979, 'grad_norm': 97.82688903808594, 'learning_rate': 4.995066821070679e-05, 'rewards/chosen': -1.0832438468933105, 'rewards/rejected': -1.0657503604888916, 'rewards/accuracies': 0.5, 'rewards/margins': -0.017493505030870438, 'logps/chosen': -635.9117431640625, 'logps/rejected': -524.65625, 'logits/chosen': 3.1924617290496826, 'logits/rejected': 3.5394859313964844, 'epoch': 0.03}
# {'loss': 0.4019, 'grad_norm': 54.1212158203125, 'learning_rate': 4.9889049115077005e-05, 'rewards/chosen': -0.3383314609527588, 'rewards/rejected': -1.251573085784912, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.9132415056228638, 'logps/chosen': -525.0319213867188, 'logps/rejected': -437.7425231933594, 'logits/chosen': 2.693368673324585, 'logits/rejected': 2.9277055263519287, 'epoch': 0.03}
# {'loss': 0.6924, 'grad_norm': 78.20233154296875, 'learning_rate': 4.980286753286195e-05, 'rewards/chosen': -0.4780179262161255, 'rewards/rejected': -0.5679246187210083, 'rewards/accuracies': 0.4375, 'rewards/margins': 0.08990667015314102, 'logps/chosen': -454.5484619140625, 'logps/rejected': -319.00958251953125, 'logits/chosen': 1.940268635749817, 'logits/rejected': 2.7525858879089355, 'epoch': 0.03}
# {'loss': 0.7994, 'grad_norm': 82.55281066894531, 'learning_rate': 4.9692208514878444e-05, 'rewards/chosen': -1.0008822679519653, 'rewards/rejected': -0.9301134347915649, 'rewards/accuracies': 0.375, 'rewards/margins': -0.0707688182592392, 'logps/chosen': -335.3284912109375, 'logps/rejected': -274.4847106933594, 'logits/chosen': 4.60340690612793, 'logits/rejected': 3.07877254486084, 'epoch': 0.03}
# {'loss': 0.6872, 'grad_norm': 85.0771484375, 'learning_rate': 4.9557181268217227e-05, 'rewards/chosen': -0.6072556972503662, 'rewards/rejected': -0.8840324878692627, 'rewards/accuracies': 0.4375, 'rewards/margins': 0.2767767012119293, 'logps/chosen': -467.00836181640625, 'logps/rejected': -321.6850280761719, 'logits/chosen': 2.740424156188965, 'logits/rejected': 3.2936205863952637, 'epoch': 0.03}
# {'loss': 0.5444, 'grad_norm': 64.97210693359375, 'learning_rate': 4.939791904846869e-05, 'rewards/chosen': -0.4093415141105652, 'rewards/rejected': -1.1791366338729858, 'rewards/accuracies': 0.75, 'rewards/margins': 0.7697951793670654, 'logps/chosen': -354.77581787109375, 'logps/rejected': -395.29620361328125, 'logits/chosen': 3.966233015060425, 'logits/rejected': 3.4517927169799805, 'epoch': 0.03}
# {'loss': 0.619, 'grad_norm': 87.27447509765625, 'learning_rate': 4.9214579028215776e-05, 'rewards/chosen': -1.051348328590393, 'rewards/rejected': -1.3365501165390015, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.285201758146286, 'logps/chosen': -564.5091552734375, 'logps/rejected': -433.57379150390625, 'logits/chosen': 2.5689830780029297, 'logits/rejected': 2.5840442180633545, 'epoch': 0.03}
# {'loss': 0.6311, 'grad_norm': 77.00167083740234, 'learning_rate': 4.900734214192358e-05, 'rewards/chosen': -0.667229175567627, 'rewards/rejected': -1.1331487894058228, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.4659196436405182, 'logps/chosen': -385.5240173339844, 'logps/rejected': -381.55401611328125, 'logits/chosen': 2.1275992393493652, 'logits/rejected': 2.436391592025757, 'epoch': 0.03}
# {'loss': 0.5971, 'grad_norm': 72.57650756835938, 'learning_rate': 4.877641290737884e-05, 'rewards/chosen': -0.6961174011230469, 'rewards/rejected': -1.152104139328003, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.45598679780960083, 'logps/chosen': -468.83953857421875, 'logps/rejected': -463.48858642578125, 'logits/chosen': 1.6992284059524536, 'logits/rejected': 2.482492685317993, 'epoch': 0.03}
# {'loss': 0.6687, 'grad_norm': 97.62580871582031, 'learning_rate': 4.852201922385564e-05, 'rewards/chosen': -0.5855453014373779, 'rewards/rejected': -1.0523457527160645, 'rewards/accuracies': 0.625, 'rewards/margins': 0.4668005704879761, 'logps/chosen': -554.7503051757812, 'logps/rejected': -437.59466552734375, 'logits/chosen': 2.8280019760131836, 'logits/rejected': 2.4479644298553467, 'epoch': 0.03}
# {'loss': 0.6885, 'grad_norm': 75.99615478515625, 'learning_rate': 4.8244412147206284e-05, 'rewards/chosen': -0.6962772607803345, 'rewards/rejected': -0.9882779717445374, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.2920006513595581, 'logps/chosen': -485.4819641113281, 'logps/rejected': -403.55792236328125, 'logits/chosen': 2.2686607837677, 'logits/rejected': 2.478015184402466, 'epoch': 0.03}
# {'loss': 0.5752, 'grad_norm': 86.91588592529297, 'learning_rate': 4.794386564209953e-05, 'rewards/chosen': -0.9267500638961792, 'rewards/rejected': -1.337602138519287, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.4108520746231079, 'logps/chosen': -336.83038330078125, 'logps/rejected': -314.9369201660156, 'logits/chosen': 2.112520694732666, 'logits/rejected': 2.2297797203063965, 'epoch': 0.03}
# {'loss': 0.7114, 'grad_norm': 87.545654296875, 'learning_rate': 4.762067631165049e-05, 'rewards/chosen': -0.9823207259178162, 'rewards/rejected': -1.5108580589294434, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.528537392616272, 'logps/chosen': -598.5657958984375, 'logps/rejected': -585.3213500976562, 'logits/chosen': 2.2655844688415527, 'logits/rejected': 1.8001434803009033, 'epoch': 0.03}
# {'loss': 0.5854, 'grad_norm': 69.5319595336914, 'learning_rate': 4.72751631047092e-05, 'rewards/chosen': -0.9342045187950134, 'rewards/rejected': -1.3937357664108276, 'rewards/accuracies': 0.75, 'rewards/margins': 0.459531307220459, 'logps/chosen': -419.92620849609375, 'logps/rejected': -369.3367614746094, 'logits/chosen': 3.7160849571228027, 'logits/rejected': 3.064920425415039, 'epoch': 0.03}
# {'loss': 0.6988, 'grad_norm': 88.5785903930664, 'learning_rate': 4.690766700109659e-05, 'rewards/chosen': -0.9069960117340088, 'rewards/rejected': -1.1599483489990234, 'rewards/accuracies': 0.625, 'rewards/margins': 0.2529523968696594, 'logps/chosen': -462.8542785644531, 'logps/rejected': -461.010498046875, 'logits/chosen': 2.969515323638916, 'logits/rejected': 3.475992202758789, 'epoch': 0.03}
# {'loss': 0.574, 'grad_norm': 78.53404235839844, 'learning_rate': 4.65185506750986e-05, 'rewards/chosen': -0.8663409948348999, 'rewards/rejected': -1.1849888563156128, 'rewards/accuracies': 0.875, 'rewards/margins': 0.3186478018760681, 'logps/chosen': -434.28790283203125, 'logps/rejected': -416.69451904296875, 'logits/chosen': 1.1415400505065918, 'logits/rejected': 0.9869396686553955, 'epoch': 0.03}
# {'loss': 0.5361, 'grad_norm': 59.83637619018555, 'learning_rate': 4.610819813755038e-05, 'rewards/chosen': -0.9631555676460266, 'rewards/rejected': -1.545337200164795, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.5821815729141235, 'logps/chosen': -273.47344970703125, 'logps/rejected': -305.967041015625, 'logits/chosen': 3.1614952087402344, 'logits/rejected': 3.0938611030578613, 'epoch': 0.03}
# {'loss': 0.7207, 'grad_norm': 122.91423034667969, 'learning_rate': 4.567701435686404e-05, 'rewards/chosen': -1.2507489919662476, 'rewards/rejected': -1.5107662677764893, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.26001718640327454, 'logps/chosen': -687.4607543945312, 'logps/rejected': -556.9999389648438, 'logits/chosen': 3.6383848190307617, 'logits/rejected': 2.626164197921753, 'epoch': 0.03}
# {'loss': 0.8293, 'grad_norm': 112.33228302001953, 'learning_rate': 4.522542485937369e-05, 'rewards/chosen': -1.4159857034683228, 'rewards/rejected': -1.506631851196289, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.09064625948667526, 'logps/chosen': -683.40869140625, 'logps/rejected': -454.347412109375, 'logits/chosen': 2.231443405151367, 'logits/rejected': 2.4593114852905273, 'epoch': 0.03}
# {'loss': 0.8607, 'grad_norm': 95.53498840332031, 'learning_rate': 4.4753875309392266e-05, 'rewards/chosen': -1.2019253969192505, 'rewards/rejected': -1.1294379234313965, 'rewards/accuracies': 0.5625, 'rewards/margins': -0.07248754799365997, 'logps/chosen': -485.5624084472656, 'logps/rejected': -409.0557861328125, 'logits/chosen': 2.573173999786377, 'logits/rejected': 3.525155544281006, 'epoch': 0.03}
# ...
# {'loss': 0.982, 'grad_norm': 113.80425262451172, 'learning_rate': 1.5071302734130489e-05, 'rewards/chosen': -1.5870444774627686, 'rewards/rejected': -1.380686640739441, 'rewards/accuracies': 0.1875, 'rewards/margins': -0.20635783672332764, 'logps/chosen': -537.52490234375, 'logps/rejected': -575.520263671875, 'logits/chosen': 3.3571720123291016, 'logits/rejected': 3.0961790084838867, 'epoch': 0.04}
# {'loss': 0.5832, 'grad_norm': 82.23233032226562, 'learning_rate': 1.4355517710873184e-05, 'rewards/chosen': -1.1315271854400635, 'rewards/rejected': -1.7610280513763428, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.6295009851455688, 'logps/chosen': -574.8688354492188, 'logps/rejected': -486.7784118652344, 'logits/chosen': 1.9974560737609863, 'logits/rejected': 1.8588979244232178, 'epoch': 0.04}
# {'loss': 0.5096, 'grad_norm': 58.095584869384766, 'learning_rate': 1.3650237506511331e-05, 'rewards/chosen': -0.6669461131095886, 'rewards/rejected': -1.3025063276290894, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.6355602145195007, 'logps/chosen': -290.05218505859375, 'logps/rejected': -371.4721984863281, 'logits/chosen': 5.024351119995117, 'logits/rejected': 3.6178743839263916, 'epoch': 0.04}
# {'loss': 0.5962, 'grad_norm': 89.47026824951172, 'learning_rate': 1.2956158147457115e-05, 'rewards/chosen': -1.199888825416565, 'rewards/rejected': -1.6646404266357422, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.46475154161453247, 'logps/chosen': -625.5057983398438, 'logps/rejected': -609.6481323242188, 'logits/chosen': 3.7002079486846924, 'logits/rejected': 3.6003599166870117, 'epoch': 0.04}
# {'loss': 0.8504, 'grad_norm': 101.88815307617188, 'learning_rate': 1.2273964606240718e-05, 'rewards/chosen': -1.711561918258667, 'rewards/rejected': -1.6157264709472656, 'rewards/accuracies': 0.5, 'rewards/margins': -0.09583547711372375, 'logps/chosen': -475.4457702636719, 'logps/rejected': -441.02020263671875, 'logits/chosen': 2.1932179927825928, 'logits/rejected': 3.1413893699645996, 'epoch': 0.04}
# {'loss': 0.7105, 'grad_norm': 99.47796630859375, 'learning_rate': 1.1604330125525079e-05, 'rewards/chosen': -0.911280632019043, 'rewards/rejected': -1.1376316547393799, 'rewards/accuracies': 0.625, 'rewards/margins': 0.22635096311569214, 'logps/chosen': -446.647216796875, 'logps/rejected': -409.916259765625, 'logits/chosen': 2.784837007522583, 'logits/rejected': 3.4221839904785156, 'epoch': 0.04}
# {'loss': 0.9533, 'grad_norm': 101.1860122680664, 'learning_rate': 1.0947915553696742e-05, 'rewards/chosen': -1.4780728816986084, 'rewards/rejected': -1.2431790828704834, 'rewards/accuracies': 0.375, 'rewards/margins': -0.23489391803741455, 'logps/chosen': -420.6219482421875, 'logps/rejected': -358.0894775390625, 'logits/chosen': 4.2078776359558105, 'logits/rejected': 3.0479753017425537, 'epoch': 0.04}
# {'loss': 0.4769, 'grad_norm': 72.81263732910156, 'learning_rate': 1.0305368692688174e-05, 'rewards/chosen': -1.0080242156982422, 'rewards/rejected': -2.0290653705596924, 'rewards/accuracies': 0.6875, 'rewards/margins': 1.0210413932800293, 'logps/chosen': -306.58697509765625, 'logps/rejected': -428.2105407714844, 'logits/chosen': 3.3416271209716797, 'logits/rejected': 4.336782932281494, 'epoch': 0.04}
# {'loss': 0.513, 'grad_norm': 68.48918914794922, 'learning_rate': 9.677323658675594e-06, 'rewards/chosen': -0.9073979258537292, 'rewards/rejected': -1.4760299921035767, 'rewards/accuracies': 0.75, 'rewards/margins': 0.5686321258544922, 'logps/chosen': -537.8314208984375, 'logps/rejected': -470.8695068359375, 'logits/chosen': 3.1211695671081543, 'logits/rejected': 2.5732293128967285, 'epoch': 0.04}
# {'loss': 0.8885, 'grad_norm': 109.7197494506836, 'learning_rate': 9.064400256282757e-06, 'rewards/chosen': -1.0285228490829468, 'rewards/rejected': -0.9972392320632935, 'rewards/accuracies': 0.5625, 'rewards/margins': -0.03128354251384735, 'logps/chosen': -312.23089599609375, 'logps/rejected': -386.0635681152344, 'logits/chosen': 2.828606128692627, 'logits/rejected': 4.129137992858887, 'epoch': 0.04}
# {'loss': 0.7931, 'grad_norm': 91.65726470947266, 'learning_rate': 8.467203366908707e-06, 'rewards/chosen': -1.2718524932861328, 'rewards/rejected': -1.5188441276550293, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.2469916045665741, 'logps/chosen': -514.4583740234375, 'logps/rejected': -423.9949951171875, 'logits/chosen': 4.681877136230469, 'logits/rejected': 4.468799591064453, 'epoch': 0.04}
# {'loss': 0.6855, 'grad_norm': 72.79927825927734, 'learning_rate': 7.886322351782783e-06, 'rewards/chosen': -0.9981868267059326, 'rewards/rejected': -1.384351134300232, 'rewards/accuracies': 0.625, 'rewards/margins': 0.3861643970012665, 'logps/chosen': -385.1583557128906, 'logps/rejected': -372.0381774902344, 'logits/chosen': 2.4728596210479736, 'logits/rejected': 1.2693763971328735, 'epoch': 0.04}
# {'loss': 0.7669, 'grad_norm': 87.38047790527344, 'learning_rate': 7.3223304703363135e-06, 'rewards/chosen': -1.4275758266448975, 'rewards/rejected': -1.5727053880691528, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.14512957632541656, 'logps/chosen': -292.3712463378906, 'logps/rejected': -275.69677734375, 'logits/chosen': 3.671032428741455, 'logits/rejected': 3.520794630050659, 'epoch': 0.05}
# {'loss': 0.5087, 'grad_norm': 55.6198844909668, 'learning_rate': 6.775784314464717e-06, 'rewards/chosen': -0.8742020726203918, 'rewards/rejected': -1.4567811489105225, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.5825791358947754, 'logps/chosen': -340.45770263671875, 'logps/rejected': -285.4245910644531, 'logits/chosen': 3.752683162689209, 'logits/rejected': 3.841334581375122, 'epoch': 0.05}
# {'loss': 0.6727, 'grad_norm': 104.09696960449219, 'learning_rate': 6.247223259238513e-06, 'rewards/chosen': -0.9398241639137268, 'rewards/rejected': -1.605965495109558, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.6661413908004761, 'logps/chosen': -496.29833984375, 'logps/rejected': -473.3813171386719, 'logits/chosen': 1.5660879611968994, 'logits/rejected': 1.7489774227142334, 'epoch': 0.05}
# {'loss': 0.3628, 'grad_norm': 54.887027740478516, 'learning_rate': 5.737168930605272e-06, 'rewards/chosen': -0.6149032115936279, 'rewards/rejected': -1.8986597061157227, 'rewards/accuracies': 0.75, 'rewards/margins': 1.2837563753128052, 'logps/chosen': -441.2707824707031, 'logps/rejected': -663.994140625, 'logits/chosen': 3.465186357498169, 'logits/rejected': 3.828371047973633, 'epoch': 0.05}
# {'loss': 0.8293, 'grad_norm': 117.4376449584961, 'learning_rate': 5.24612469060774e-06, 'rewards/chosen': -1.0350914001464844, 'rewards/rejected': -1.1097354888916016, 'rewards/accuracies': 0.5, 'rewards/margins': 0.07464410364627838, 'logps/chosen': -342.815185546875, 'logps/rejected': -242.7368621826172, 'logits/chosen': 4.817359924316406, 'logits/rejected': 4.452982425689697, 'epoch': 0.05}
# {'loss': 0.5411, 'grad_norm': 59.24629592895508, 'learning_rate': 4.7745751406263165e-06, 'rewards/chosen': -1.0713579654693604, 'rewards/rejected': -1.731603741645813, 'rewards/accuracies': 0.625, 'rewards/margins': 0.6602457761764526, 'logps/chosen': -451.2498474121094, 'logps/rejected': -281.42724609375, 'logits/chosen': 3.5567879676818848, 'logits/rejected': 2.7282114028930664, 'epoch': 0.05}
# {'loss': 0.4954, 'grad_norm': 63.57845687866211, 'learning_rate': 4.322985643135952e-06, 'rewards/chosen': -0.9614354372024536, 'rewards/rejected': -1.7347244024276733, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.7732890844345093, 'logps/chosen': -597.220703125, 'logps/rejected': -450.8853759765625, 'logits/chosen': 3.8408777713775635, 'logits/rejected': 3.57135272026062, 'epoch': 0.05}
# {'loss': 0.5636, 'grad_norm': 53.064090728759766, 'learning_rate': 3.891801862449629e-06, 'rewards/chosen': -0.9200271964073181, 'rewards/rejected': -1.5120460987091064, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.5920189619064331, 'logps/chosen': -337.73541259765625, 'logps/rejected': -286.7391052246094, 'logits/chosen': 4.064023971557617, 'logits/rejected': 3.9661288261413574, 'epoch': 0.05}
# {'loss': 0.6087, 'grad_norm': 81.07242584228516, 'learning_rate': 3.4814493249014116e-06, 'rewards/chosen': -1.2189992666244507, 'rewards/rejected': -1.5752241611480713, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.356224924325943, 'logps/chosen': -519.45556640625, 'logps/rejected': -360.0355529785156, 'logits/chosen': 3.054986000061035, 'logits/rejected': 2.959467887878418, 'epoch': 0.05}
# {'loss': 0.8548, 'grad_norm': 107.4312973022461, 'learning_rate': 3.0923329989034132e-06, 'rewards/chosen': -1.3704530000686646, 'rewards/rejected': -1.4911437034606934, 'rewards/accuracies': 0.625, 'rewards/margins': 0.12069070339202881, 'logps/chosen': -430.182861328125, 'logps/rejected': -440.4988708496094, 'logits/chosen': 3.52656626701355, 'logits/rejected': 4.15906286239624, 'epoch': 0.05}
# {'loss': 0.5671, 'grad_norm': 66.12543487548828, 'learning_rate': 2.7248368952908053e-06, 'rewards/chosen': -0.8507261872291565, 'rewards/rejected': -1.4123338460922241, 'rewards/accuracies': 0.625, 'rewards/margins': 0.5616077184677124, 'logps/chosen': -339.3078918457031, 'logps/rejected': -440.9962158203125, 'logits/chosen': 2.5173797607421875, 'logits/rejected': 3.25644588470459, 'epoch': 0.05}
# {'loss': 0.5806, 'grad_norm': 62.655948638916016, 'learning_rate': 2.379323688349516e-06, 'rewards/chosen': -1.1963900327682495, 'rewards/rejected': -1.7496452331542969, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.5532552599906921, 'logps/chosen': -459.8161926269531, 'logps/rejected': -444.0141906738281, 'logits/chosen': 3.7775988578796387, 'logits/rejected': 4.169466972351074, 'epoch': 0.05}
# {'loss': 0.7865, 'grad_norm': 77.71949768066406, 'learning_rate': 2.0561343579004715e-06, 'rewards/chosen': -1.188185214996338, 'rewards/rejected': -1.3896629810333252, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.20147788524627686, 'logps/chosen': -386.0391540527344, 'logps/rejected': -335.1741943359375, 'logits/chosen': 3.4471824169158936, 'logits/rejected': 3.2261219024658203, 'epoch': 0.05}
# {'loss': 0.5147, 'grad_norm': 65.70219421386719, 'learning_rate': 1.7555878527937164e-06, 'rewards/chosen': -0.7735869288444519, 'rewards/rejected': -1.4209847450256348, 'rewards/accuracies': 0.75, 'rewards/margins': 0.6473978161811829, 'logps/chosen': -289.01849365234375, 'logps/rejected': -349.73992919921875, 'logits/chosen': 2.806490898132324, 'logits/rejected': 2.896545886993408, 'epoch': 0.05}
# {'loss': 0.7746, 'grad_norm': 91.63068389892578, 'learning_rate': 1.4779807761443636e-06, 'rewards/chosen': -1.2061071395874023, 'rewards/rejected': -1.2706772089004517, 'rewards/accuracies': 0.5, 'rewards/margins': 0.06457008421421051, 'logps/chosen': -420.66510009765625, 'logps/rejected': -461.28521728515625, 'logits/chosen': 1.1416743993759155, 'logits/rejected': 2.8769805431365967, 'epoch': 0.05}
# {'loss': 0.5293, 'grad_norm': 68.04582977294922, 'learning_rate': 1.2235870926211619e-06, 'rewards/chosen': -0.7978044748306274, 'rewards/rejected': -1.2748255729675293, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.47702115774154663, 'logps/chosen': -369.0422668457031, 'logps/rejected': -380.32647705078125, 'logits/chosen': 2.7938156127929688, 'logits/rejected': 2.266045570373535, 'epoch': 0.05}
# {'loss': 0.8155, 'grad_norm': 90.75882720947266, 'learning_rate': 9.926578580764234e-07, 'rewards/chosen': -1.3101394176483154, 'rewards/rejected': -1.3457772731781006, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.03563789278268814, 'logps/chosen': -398.9292907714844, 'logps/rejected': -356.54833984375, 'logits/chosen': 3.543313980102539, 'logits/rejected': 4.082137584686279, 'epoch': 0.05}
# {'loss': 0.6976, 'grad_norm': 73.02275848388672, 'learning_rate': 7.854209717842231e-07, 'rewards/chosen': -0.916228175163269, 'rewards/rejected': -1.3120917081832886, 'rewards/accuracies': 0.625, 'rewards/margins': 0.39586353302001953, 'logps/chosen': -321.0898132324219, 'logps/rejected': -317.6795654296875, 'logits/chosen': 2.9032323360443115, 'logits/rejected': 2.3333096504211426, 'epoch': 0.05}
# {'loss': 0.6927, 'grad_norm': 82.49299621582031, 'learning_rate': 6.020809515313142e-07, 'rewards/chosen': -1.2094146013259888, 'rewards/rejected': -1.3753780126571655, 'rewards/accuracies': 0.4375, 'rewards/margins': 0.16596341133117676, 'logps/chosen': -428.6659240722656, 'logps/rejected': -337.6121826171875, 'logits/chosen': 2.6426825523376465, 'logits/rejected': 2.6113572120666504, 'epoch': 0.05}
# {'loss': 0.6433, 'grad_norm': 76.18617248535156, 'learning_rate': 4.4281873178278475e-07, 'rewards/chosen': -1.3350931406021118, 'rewards/rejected': -1.6216074228286743, 'rewards/accuracies': 0.625, 'rewards/margins': 0.2865142226219177, 'logps/chosen': -544.4124755859375, 'logps/rejected': -410.69146728515625, 'logits/chosen': 2.483879566192627, 'logits/rejected': 1.6511683464050293, 'epoch': 0.05}
# {'loss': 0.6661, 'grad_norm': 67.89665222167969, 'learning_rate': 3.077914851215585e-07, 'rewards/chosen': -1.0758589506149292, 'rewards/rejected': -1.5147457122802734, 'rewards/accuracies': 0.75, 'rewards/margins': 0.43888676166534424, 'logps/chosen': -328.24420166015625, 'logps/rejected': -307.28619384765625, 'logits/chosen': 3.805568218231201, 'logits/rejected': 3.5282859802246094, 'epoch': 0.05}
# {'loss': 0.7302, 'grad_norm': 91.5357437133789, 'learning_rate': 1.9713246713805588e-07, 'rewards/chosen': -1.2827491760253906, 'rewards/rejected': -1.5106568336486816, 'rewards/accuracies': 0.625, 'rewards/margins': 0.2279076874256134, 'logps/chosen': -469.0770568847656, 'logps/rejected': -524.3064575195312, 'logits/chosen': 1.9550297260284424, 'logits/rejected': 2.655653476715088, 'epoch': 0.05}
# {'loss': 0.8258, 'grad_norm': 96.71599578857422, 'learning_rate': 1.109508849230001e-07, 'rewards/chosen': -1.6095049381256104, 'rewards/rejected': -1.6533743143081665, 'rewards/accuracies': 0.4375, 'rewards/margins': 0.04386933892965317, 'logps/chosen': -443.148681640625, 'logps/rejected': -360.3082580566406, 'logits/chosen': 2.7410178184509277, 'logits/rejected': 3.5257151126861572, 'epoch': 0.05}
# {'loss': 0.7418, 'grad_norm': 73.26773834228516, 'learning_rate': 4.9331789293211026e-08, 'rewards/chosen': -0.9304758310317993, 'rewards/rejected': -1.056341290473938, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.12586548924446106, 'logps/chosen': -312.2861633300781, 'logps/rejected': -344.7248840332031, 'logits/chosen': 2.3034071922302246, 'logits/rejected': 2.395421266555786, 'epoch': 0.05}
# {'loss': 0.763, 'grad_norm': 77.84101867675781, 'learning_rate': 1.233599085671e-08, 'rewards/chosen': -1.0849990844726562, 'rewards/rejected': -1.2478992938995361, 'rewards/accuracies': 0.625, 'rewards/margins': 0.16290023922920227, 'logps/chosen': -342.6981506347656, 'logps/rejected': -211.28341674804688, 'logits/chosen': 3.417569637298584, 'logits/rejected': 2.430560827255249, 'epoch': 0.05}
# {'loss': 0.693, 'grad_norm': 78.07810974121094, 'learning_rate': 0.0, 'rewards/chosen': -1.35733163356781, 'rewards/rejected': -1.4731264114379883, 'rewards/accuracies': 0.625, 'rewards/margins': 0.11579480022192001, 'logps/chosen': -315.7129211425781, 'logps/rejected': -443.4224853515625, 'logits/chosen': 3.9367289543151855, 'logits/rejected': 4.262981414794922, 'epoch': 0.05}
# {'train_runtime': 1133.7044, 'train_samples_per_second': 2.823, 'train_steps_per_second': 0.176, 'train_loss': 0.6625723943114281, 'epoch': 0.05}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Train the model
#       2 trainer.train()
# ----> 3 x
#       4 # Save the model
#       5 trainer.save_model(f"./{finetune_name}")
#
# NameError: name 'x' is not defined

# %%
# Save the model
trainer.save_model(f"./{finetune_name}")

# Save to the huggingface hub if login (HF_TOKEN is set)
if os.getenv("HF_TOKEN"):
    trainer.push_to_hub(tags=finetune_tags)

# %%
trainer.push_to_hub(tags=finetune_tags)
# Out:
# model.safetensors:   0%|          | 0.00/538M [00:00<?, ?B/s]
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# training_args.bin:   0%|          | 0.00/6.07k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/herooooooooo/SmolLM2-FT-DPO/commit/e9f531fd0d7fe79cae6dafc28bf80c6295e95ff2', commit_message='End of training', commit_description='', oid='e9f531fd0d7fe79cae6dafc28bf80c6295e95ff2', pr_url=None, repo_url=RepoUrl('https://huggingface.co/herooooooooo/SmolLM2-FT-DPO', endpoint='https://huggingface.co', repo_type='model', repo_id='herooooooooo/SmolLM2-FT-DPO'), pr_revision=None, pr_num=None)
